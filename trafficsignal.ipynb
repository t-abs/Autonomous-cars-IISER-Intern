# %%
import os
import cv2
import pickle
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support as prfs

from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model, save_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Dropout, Dense, Flatten

# %matplotlib inline
print("[Done] Libraries imported...")
# Out:
# 2024-06-03 07:37:42.024194: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-03 07:37:42.024402: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-03 07:37:42.192464: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [Done] Libraries imported...

# %%
# Function to load data from path
def load_data(data_path):
    X = []
    y = []
    labels = os.listdir(data_path)
    img_path_per_label = {labels[i]: [os.path.join(data_path, labels[i], img_path) for img_path in os.listdir(data_path + '/' + labels[i])] for i in range(len(labels))}
    for key in list(img_path_per_label.keys()):
        for img_path in img_path_per_label[key]:
            X.append(cv2.resize(cv2.imread(img_path), (30, 30), interpolation=cv2.INTER_BITS2))
            y.append(key)

    return np.array(X), np.array(y)

# %%
# Function to increase brightness of images
def increase_brightness(img, value=20):
    hsv_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    h, s, v = cv2.split(hsv_img)

    limit = 255 - value
    v[v <= limit] += value
    v[v > limit] = 255

    final_hsv = cv2.merge((h, s, v))
    return cv2.cvtColor(final_hsv, cv2.COLOR_HSV2BGR)

# %%
# Function to display random set of images from dataset
def display_random_set(data, labels):
    for i in range(10):
        random_val = np.random.randint(low=0, high=len(data))
        plt.subplot(2, 5, (i + 1))
        plt.imshow(data[random_val])
        plt.title(labels[random_val])
        plt.axis(False)
    plt.show()

# %%
# Convolutional Neural Network model
def build_model(num_classes, img_dim):
    model = Sequential()

    model.add(Conv2D(filters=64, kernel_size=(2, 2), padding='same', activation='relu', input_shape=img_dim))
    model.add(BatchNormalization())

    model.add(Conv2D(filters=64, kernel_size=(2, 2), padding='same', activation='relu'))
    model.add(BatchNormalization())

    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=128, kernel_size=(2, 2), padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.1))

    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    sgd = SGD(learning_rate=0.001, nesterov=True, name='SGD_Optimizer')
    model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['categorical_accuracy', 'mse'])

    print(model.summary())

    return model

# %%
# Training Model
def train_model(x, y, x_val, y_val, model, train=False):
    batch_size = 64
    num_epochs = 25
    if train:
        checkpoint = ModelCheckpoint(filepath='traffic_sign_model.h5', monitor='val_loss', save_best_only=True, verbose=1)
        history = model.fit(x=x, y=y, validation_data=(x_val, y_val), shuffle=True, batch_size=batch_size, epochs=num_epochs, callbacks=[checkpoint], verbose=1)
        save_history_file(file_name='traffic_sign.pickle', history=history)

# %%
def save_history_file(file_name, history):
    pickle_out = open(file_name, 'wb')
    pickle.dump(history.history, pickle_out)
    pickle_out.close()


def load_history(file_name):
    pickle_in = open(file_name, 'rb')
    saved_hist = pickle.load(pickle_in)
    return saved_hist

# %%
# Functions to plot loss curves and accuracy per class
def plot_curves(history):

    plt.figure(figsize=(10, 5))
    sns.set_style(style='dark')
    plt.subplot(1, 2, 1)
    plt.plot(history['loss'])
    plt.plot(history['val_loss'])
    plt.xlabel('Iterations')
    plt.ylabel('Error')
    plt.title('Training & Validation Loss')
    plt.legend(['Train loss', 'Validation loss'])

    plt.subplot(1, 2, 2)
    plt.plot(history['mse'])
    plt.plot(history['val_mse'])
    plt.xlabel('Iterations')
    plt.ylabel('Error')
    plt.title('Training & Validation MSE')
    plt.legend(['Train mse', 'Validation mse'])

    plt.show()


def accuracy_per_class(labels, precision, recall, f1):
    # plt.subplots(figsize=(18, 30))

    x = range(len(labels))
    plt.subplot(3, 1, 1)
    plt.title("Precision per class")
    plt.ylim(0, 1.00)
    plt.bar(x, precision, color='Red')
    plt.xticks(x, rotation=90)

    plt.subplot(312)
    plt.title('Recall per class')
    plt.ylim(0, 1.00)
    plt.bar(x, recall, color='Green')
    plt.xticks(x, rotation=90)

    plt.subplot(313)
    plt.title('F1 score per class')
    plt.ylim(0, 1.00)
    plt.bar(x, f1, color='Blue')
    plt.xticks(x, rotation=90)
    plt.show()

# %%
 #Loading Test data
def load_test_data(test_data_dir, test_data_labels_dir):
    # reading csv file
    data = np.loadtxt(test_data_labels_dir, delimiter=',', skiprows=1, dtype=str)
    x_test = np.array([os.path.join(test_data_dir, img_name) for img_name in data[:, 0]])
    x_test = np.array([cv2.resize(cv2.imread(img_path), (30, 30), interpolation=cv2.INTER_BITS2) for img_path in x_test])
    y_test = np.array(data[:, 1]).astype(np.int)

    return x_test, y_test

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.models import load_model
from sklearn.metrics import precision_recall_fscore_support as prfs
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint

def main():
    # Reading Data from folders
    X, y = load_data(data_path='../input/traffic-sign-cropped/crop_dataset/crop_dataset/')
    print(f"Data shape: {X.shape},   Labels: {y.shape}\n")

    # Displaying random set of images from data
    display_random_set(data=X, labels=y)

    # Splitting data into training and testing data, training will consist of 70% of the data and 30% of the remaining
    # will be testing data.
    x_train, x_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=42, shuffle=True)
    print(f"Training Data: {x_train.shape},   Training labels: {y_train.shape}\nValidation Data: {x_val.shape},   "
          f"Validation labels: {y_val.shape}\n")

    # Adjusting labels to be represented as categorical data.
    num_classes = len(np.unique(y))
    y_train = to_categorical(y_train, num_classes=num_classes)
    y_val = to_categorical(y_val, num_classes=num_classes)

    # Creating Neural network model.
    model = build_model(num_classes=num_classes, img_dim=x_train[0].shape)

    # To train the model again change train value to True, change to False to not train.
    train_model(x=x_train, y=y_train, x_val=x_val, y_val=y_val, model=model, train=True)
    print("[In progress] Loading Keras model and history file...")
    classifier = load_model(filepath='traffic_sign_model.keras')
    hist_loaded = load_history(file_name='traffic_sign.pickle')
    print("[Done] Loading Keras model and history file...")

    # Loading data for testing model.
    x_test, y_test = load_test_data(test_data_dir='../input/traffic-sign-cropped/test_data/test_data', test_data_labels_dir='../input/traffic-sign-cropped/test_labels.csv')
    predictions = classifier.predict_classes(x_test)
    accuracy = np.array([1 if predictions[i] == int(y_test[i]) else 0 for i in range(len(predictions))])
    print(f"Accuracy on test data: {np.mean(accuracy) * 100} %.")

    # plotting loss and mse curves for training and validation steps
    plot_curves(hist_loaded)
    
    # plotting accuracy bar graph per class
    labels = np.unique(y)
    precision, recall, f1, support = prfs(y_true=y_test, y_pred=predictions, average=None)
    accuracy_per_class(labels, precision, recall, f1) 

# Function to train the model
def train_model(x, y, x_val, y_val, model, train):
    batch_size = 32
    num_epochs = 25
    if train:
        checkpoint = ModelCheckpoint(filepath='traffic_sign_model.keras', monitor='val_loss', save_best_only=True, verbose=1)
        history = model.fit(x=x, y=y, validation_data=(x_val, y_val), shuffle=True, batch_size=batch_size, epochs=num_epochs, callbacks=[checkpoint], verbose=1)
        save_history_file(file_name='traffic_sign.pickle', history=history)

# Call the main function
main()
# Out:
# Data shape: (26640, 30, 30, 3),   Labels: (26640,)
# Training Data: (18648, 30, 30, 3),   Training labels: (18648,)
# Validation Data: (7992, 30, 30, 3),   Validation labels: (7992,)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 30, 30, 64)     │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 30, 30, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 30, 30, 64)     │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 30, 30, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 15, 15, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 15, 15, 128)    │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 15, 15, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 7, 7, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 7, 7, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 6272)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │     1,605,888 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 43)             │         2,795 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,742,123 (6.65 MB)
#  Trainable params: 1,741,611 (6.64 MB)
#  Non-trainable params: 512 (2.00 KB)
# None
# Epoch 1/25
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - categorical_accuracy: 0.1494 - loss: 3.3762 - mse: 0.0216
# Epoch 1: val_loss improved from inf to 2.11944, saving model to traffic_sign_model.keras
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 65s 109ms/step - categorical_accuracy: 0.1495 - loss: 3.3754 - mse: 0.0216 - val_categorical_accuracy: 0.4432 - val_loss: 2.1194 - val_mse: 0.0163
# Epoch 2/25
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - categorical_accuracy: 0.5180 - loss: 1.8333 - mse: 0.0146
# Epoch 2: val_loss improved from 2.11944 to 1.18225, saving model to traffic_sign_model.keras
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 64s 110ms/step - categorical_accuracy: 0.5181 - loss: 1.8329 - mse: 0.0146 - val_categorical_accuracy: 0.7028 - val_loss: 1.1822 - val_mse: 0.0105
# Epoch 3/25
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - categorical_accuracy: 0.7204 - loss: 1.0429 - mse: 0.0094
# Epoch 3: val_loss improved from 1.18225 to 0.68840, saving model to traffic_sign_model.keras
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 62s 107ms/step - categorical_accuracy: 0.7205 - loss: 1.0427 - mse: 0.0094 - val_categorical_accuracy: 0.8246 - val_loss: 0.6884 - val_mse: 0.0065
# Epoch 4/25
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - categorical_accuracy: 0.8315 - loss: 0.6492 - mse: 0.0062
# Epoch 4: val_loss improved from 0.68840 to 0.47197, saving model to traffic_sign_model.keras
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 63s 108ms/step - categorical_accuracy: 0.8316 - loss: 0.6491 - mse: 0.0062 - val_categorical_accuracy: 0.8900 - val_loss: 0.4720 - val_mse: 0.0045
# Epoch 5/25
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 0.8977 - loss: 0.4264 - mse: 0.0041
# Epoch 5: val_loss improved from 0.47197 to 0.33865, saving model to traffic_sign_model.keras
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 62s 107ms/step - categorical_accuracy: 0.8977 - loss: 0.4264 - mse: 0.0041 - val_categorical_accuracy: 0.9194 - val_loss: 0.3387 - val_mse: 0.0032
# Epoch 6/25
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 0.9301 - loss: 0.3039 - mse: 0.0029
# Epoch 6: val_loss improved from 0.33865 to 0.26725, saving model to traffic_sign_model.keras
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 62s 106ms/step - categorical_accuracy: 0.9301 - loss: 0.3039 - mse: 0.0029 - val_categorical_accuracy: 0.9431 - val_loss: 0.2673 - val_mse: 0.0025
# Epoch 7/25
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 0.9434 - loss: 0.2423 - mse: 0.0023
# Epoch 7: val_loss improved from 0.26725 to 0.21361, saving model to traffic_sign_model.keras
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 62s 106ms/step - categorical_accuracy: 0.9434 - loss: 0.2423 - mse: 0.0023 - val_categorical_accuracy: 0.9546 - val_loss: 0.2136 - val_mse: 0.0020
# Epoch 8/25
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 0.9576 - loss: 0.1898 - mse: 0.0018
# Epoch 8: val_loss improved from 0.21361 to 0.18738, saving model to traffic_sign_model.keras
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 62s 106ms/step - categorical_accuracy: 0.9576 - loss: 0.1898 - mse: 0.0018 - val_categorical_accuracy: 0.9623 - val_loss: 0.1874 - val_mse: 0.0017
# Epoch 9/25
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - categorical_accuracy: 0.9670 - loss: 0.1562 - mse: 0.0015
# Epoch 9: val_loss improved from 0.18738 to 0.16824, saving model to traffic_sign_model.keras
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 63s 108ms/step - categorical_accuracy: 0.9670 - loss: 0.1562 - mse: 0.0015 - val_categorical_accuracy: 0.9623 - val_loss: 0.1682 - val_mse: 0.0015
# Epoch 10/25
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 0.9731 - loss: 0.1293 - mse: 0.0012
# Epoch 10: val_loss improved from 0.16824 to 0.15189, saving model to traffic_sign_model.keras
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 62s 107ms/step - categorical_accuracy: 0.9731 - loss: 0.1293 - mse: 0.0012 - val_categorical_accuracy: 0.9677 - val_loss: 0.1519 - val_mse: 0.0013
# Epoch 11/25
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 0.9753 - loss: 0.1168 - mse: 0.0011
# Epoch 11: val_loss improved from 0.15189 to 0.13393, saving model to traffic_sign_model.keras
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 62s 107ms/step - categorical_accuracy: 0.9753 - loss: 0.1168 - mse: 0.0011 - val_categorical_accuracy: 0.9726 - val_loss: 0.1339 - val_mse: 0.0012
# Epoch 12/25
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - categorical_accuracy: 0.9821 - loss: 0.0959 - mse: 8.5675e-04
# Epoch 12: val_loss improved from 0.13393 to 0.12204, saving model to traffic_sign_model.keras
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 63s 107ms/step - categorical_accuracy: 0.9821 - loss: 0.0959 - mse: 8.5674e-04 - val_categorical_accuracy: 0.9743 - val_loss: 0.1220 - val_mse: 0.0011
# Epoch 13/25
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - categorical_accuracy: 0.9834 - loss: 0.0864 - mse: 7.8018e-04
# Epoch 13: val_loss improved from 0.12204 to 0.12117, saving model to traffic_sign_model.keras
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 63s 108ms/step - categorical_accuracy: 0.9834 - loss: 0.0863 - mse: 7.8017e-04 - val_categorical_accuracy: 0.9730 - val_loss: 0.1212 - val_mse: 0.0011
# Epoch 14/25
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - categorical_accuracy: 0.9872 - loss: 0.0732 - mse: 6.5050e-04
# Epoch 14: val_loss improved from 0.12117 to 0.10976, saving model to traffic_sign_model.keras
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 64s 110ms/step - categorical_accuracy: 0.9872 - loss: 0.0732 - mse: 6.5053e-04 - val_categorical_accuracy: 0.9784 - val_loss: 0.1098 - val_mse: 9.3036e-04
# Epoch 15/25
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - categorical_accuracy: 0.9871 - loss: 0.0706 - mse: 6.2559e-04
# Epoch 15: val_loss improved from 0.10976 to 0.10323, saving model to traffic_sign_model.keras
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 64s 111ms/step - categorical_accuracy: 0.9871 - loss: 0.0706 - mse: 6.2557e-04 - val_categorical_accuracy: 0.9791 - val_loss: 0.1032 - val_mse: 8.6224e-04
# Epoch 16/25
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - categorical_accuracy: 0.9891 - loss: 0.0599 - mse: 5.1093e-04
# Epoch 16: val_loss improved from 0.10323 to 0.09945, saving model to traffic_sign_model.keras
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 64s 109ms/step - categorical_accuracy: 0.9891 - loss: 0.0599 - mse: 5.1098e-04 - val_categorical_accuracy: 0.9795 - val_loss: 0.0995 - val_mse: 8.3864e-04
# Epoch 17/25
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - categorical_accuracy: 0.9910 - loss: 0.0561 - mse: 4.8499e-04
# Epoch 17: val_loss improved from 0.09945 to 0.09738, saving model to traffic_sign_model.keras
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 64s 109ms/step - categorical_accuracy: 0.9910 - loss: 0.0561 - mse: 4.8500e-04 - val_categorical_accuracy: 0.9801 - val_loss: 0.0974 - val_mse: 8.2487e-04
# Epoch 18/25
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - categorical_accuracy: 0.9917 - loss: 0.0509 - mse: 4.3429e-04
# Epoch 18: val_loss did not improve from 0.09738
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 63s 108ms/step - categorical_accuracy: 0.9917 - loss: 0.0509 - mse: 4.3428e-04 - val_categorical_accuracy: 0.9775 - val_loss: 0.0990 - val_mse: 8.5928e-04
# Epoch 19/25
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - categorical_accuracy: 0.9932 - loss: 0.0461 - mse: 3.8869e-04
# Epoch 19: val_loss improved from 0.09738 to 0.09013, saving model to traffic_sign_model.keras
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 83s 110ms/step - categorical_accuracy: 0.9932 - loss: 0.0461 - mse: 3.8868e-04 - val_categorical_accuracy: 0.9814 - val_loss: 0.0901 - val_mse: 7.5432e-04
# Epoch 20/25
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - categorical_accuracy: 0.9919 - loss: 0.0455 - mse: 3.8202e-04
# Epoch 20: val_loss improved from 0.09013 to 0.08653, saving model to traffic_sign_model.keras
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 63s 108ms/step - categorical_accuracy: 0.9919 - loss: 0.0455 - mse: 3.8201e-04 - val_categorical_accuracy: 0.9814 - val_loss: 0.0865 - val_mse: 7.2484e-04
# Epoch 21/25
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - categorical_accuracy: 0.9950 - loss: 0.0383 - mse: 3.0520e-04
# Epoch 21: val_loss improved from 0.08653 to 0.08649, saving model to traffic_sign_model.keras
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 64s 109ms/step - categorical_accuracy: 0.9950 - loss: 0.0383 - mse: 3.0521e-04 - val_categorical_accuracy: 0.9827 - val_loss: 0.0865 - val_mse: 7.0700e-04
# Epoch 22/25
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - categorical_accuracy: 0.9938 - loss: 0.0390 - mse: 3.2303e-04
# Epoch 22: val_loss improved from 0.08649 to 0.08173, saving model to traffic_sign_model.keras
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 63s 108ms/step - categorical_accuracy: 0.9938 - loss: 0.0390 - mse: 3.2301e-04 - val_categorical_accuracy: 0.9836 - val_loss: 0.0817 - val_mse: 6.7342e-04
# Epoch 23/25
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - categorical_accuracy: 0.9958 - loss: 0.0333 - mse: 2.5931e-04
# Epoch 23: val_loss did not improve from 0.08173
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 64s 110ms/step - categorical_accuracy: 0.9958 - loss: 0.0333 - mse: 2.5933e-04 - val_categorical_accuracy: 0.9820 - val_loss: 0.0820 - val_mse: 6.8124e-04
# Epoch 24/25
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - categorical_accuracy: 0.9963 - loss: 0.0302 - mse: 2.3794e-04
# Epoch 24: val_loss improved from 0.08173 to 0.08088, saving model to traffic_sign_model.keras
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 63s 109ms/step - categorical_accuracy: 0.9963 - loss: 0.0302 - mse: 2.3798e-04 - val_categorical_accuracy: 0.9837 - val_loss: 0.0809 - val_mse: 6.6918e-04
# Epoch 25/25
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - categorical_accuracy: 0.9963 - loss: 0.0285 - mse: 2.1492e-04
# Epoch 25: val_loss improved from 0.08088 to 0.07901, saving model to traffic_sign_model.keras
# 583/583 ━━━━━━━━━━━━━━━━━━━━ 63s 108ms/step - categorical_accuracy: 0.9963 - loss: 0.0285 - mse: 2.1492e-04 - val_categorical_accuracy: 0.9831 - val_loss: 0.0790 - val_mse: 6.4823e-04
# [In progress] Loading Keras model and history file...
# [Done] Loading Keras model and history file...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 62
#      59         save_history_file(file_name='traffic_sign.pickle', history=history)
#      61 # Call the main function
# ---> 62 main()
#
# Cell In[25], line 39, in main()
#      36 print("[Done] Loading Keras model and history file...")
#      38 # Loading data for testing model.
# ---> 39 x_test, y_test = load_test_data(test_data_dir='../input/traffic-sign-cropped/test_data/test_data', test_data_labels_dir='../input/traffic-sign-cropped/test_labels.csv')
#      40 predictions = classifier.predict_classes(x_test)
#      41 accuracy = np.array([1 if predictions[i] == int(y_test[i]) else 0 for i in range(len(predictions))])
#
# Cell In[19], line 7, in load_test_data(test_data_dir, test_data_labels_dir)
#       5 x_test = np.array([os.path.join(test_data_dir, img_name) for img_name in data[:, 0]])
#       6 x_test = np.array([cv2.resize(cv2.imread(img_path), (30, 30), interpolation=cv2.INTER_BITS2) for img_path in x_test])
# ----> 7 y_test = np.array(data[:, 1]).astype(np.int)
#       9 return x_test, y_test
#
# File /opt/conda/lib/python3.10/site-packages/numpy/__init__.py:324, in __getattr__(attr)
#     319     warnings.warn(
#     320         f"In the future `np.{attr}` will be defined as the "
#     321         "corresponding NumPy scalar.", FutureWarning, stacklevel=2)
#     323 if attr in __former_attrs__:
# --> 324     raise AttributeError(__former_attrs__[attr])
#     326 if attr == 'testing':
#     327     import numpy.testing as testing
#
# AttributeError: module 'numpy' has no attribute 'int'.
# `np.int` was a deprecated alias for the builtin `int`. To avoid this error in existing code, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
